# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
SIZE=180
gen = ['Female', 'Male',]
genero= np.random.choice(gen, SIZE) 
tv=np.around(np.random.uniform(low=0.0, high=12.01, size=(SIZE,)), decimals=1)
pc=np.around( np.random.uniform(low=0.0, high=18.01, size=(SIZE,))  , decimals=1)
dormir=np.around( np.random.uniform(low=0.0, high=9.01, size=(SIZE,)) , decimals=1) 
A1= np.around( np.random.uniform(low=0.0, high=192.01, size=(SIZE,)), decimals=1)
A2=np.around(np.random.uniform(low=0.0, high=169.01, size=(SIZE,)), decimals=1)
A3=np.around(np.random.uniform(low=0.0, high=192.01, size=(SIZE,)), decimals=1)
Ej=np.around(np.random.uniform(low=0.0, high=9.01, size=(SIZE,)), decimals=1)
prom=np.around(np.random.uniform(low=3.0, high=5.01, size=(SIZE,)), decimals=1)

data={
    'Genero':genero,
    'TV':tv,
    'Computador':pc,
    'Dormir':dormir,
    'AlturaE':A1,
    'AlturaMama':A2,
    'AlturaPapa':A3,
    'EjercicioE':Ej,
    'Promedio':prom
}
 
students = pd.DataFrame(data, columns= ['Genero', 'TV','Computador','Dormir','AlturaE','AlturaMama','AlturaPapa','EjercicioE','Promedio'])
#students.to_csv (r'data.csv', index = False, header=True) 
#students=pd.read_csv("data.csv") 
g=sns.FacetGrid(students,palette="Set1",size=7)
g.map(plt.scatter,"AlturaMama","AlturaE",s=140,linewidth=.7,edgecolor="#ffad40",color="#ff8000")
g.set_axis_labels("Mothers Height","Students Height")
print("")
g=sns.FacetGrid(students,palette="Set1",size=7)
g.map(plt.scatter,"TV","Promedio",s=140,linewidth=.7,edgecolor="#ffad40",color="#ff8000")
g.set_axis_labels("Televisión","Promedio")

print("")
g=sns.FacetGrid(students,palette="Set1",size=7)
g.map(plt.scatter,"Dormir","Computador",s=140,linewidth=.7,edgecolor="#ffad40",color="#ff8000")
g.set_axis_labels("Dormir","Computador")
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python37\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set(style="whitegrid")
altura=pd.read_csv("data.csv") 
x=altura.AlturaE  
y=altura.AlturaMama
z=altura.AlturaPapa
cm=plt.cm.get_cmap("RdYlBu")
fig, ax =plt.subplots(figsize=(12,10))
sc=ax.scatter(x,y,s=z*3,c=z,cmap=cm,linewidth=0.2, alpha=0.5)
#sc=ax.scatter(x,y,s=z*3,c=z,cmap=cm,linewidth=0.2, alpha=0.5) //no sirve al
ax.grid()
fig.colorbar(sc)
ax.set_xlabel('Altura Estudiante',fontsize=14)
ax.set_ylabel('Altura Mama',fontsize=14)
plt.show()

# %%
import matplotlib as mpl
from numpy.random import randn
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_palette("hls")
mpl.rc("figure",figsize=(10,6))  
plt.title("KDE Demostration using Seaborn and Matplotlib",fontsize=20)
sns.distplot(data,color="#ff8000")

# %%
from scipy.stats.kde import gaussian_kde
from scipy.stats import norm
from numpy import linspace, hstack
from pylab import plot, show, hist
sample1=norm.rvs(loc=-1.0,scale=1,size=320)
sample2=norm.rvs(loc=2.0,scale=0.6, size=320)
sample=hstack([sample1,sample2])
probDensityFun=gaussian_kde(sample)
plt.title("KDE Demostration using Scipy and Numpy",fontsize=20)
x=linspace(-5,5,200)
plot(x,probDensityFun(x),'r')
hist(sample,normed=1,alpha=0.45,color='purple')
show()
# Out:
# C:\Users\ASUS\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:12: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   if sys.path[0] == '':

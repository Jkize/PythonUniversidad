# %% [markdown]
# ###Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
x=(4,8,13,17,20)
y=(54,67,98,78,45)
plt.plot(x,y) 
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
num_bins=6
n,bins,patches=plt.hist(x,num_bins,facecolor='green')

# %%
plt.figure()
x=np.arange(-5,5,0.01) 
y=np.arange(-5,5,0.01)
X, Y=np.meshgrid(x,y)
#Definimos cos (x^3 + y^2)
fxy=np.cos(X**3 + Y**2)
plt.imshow(fxy)
plt.colorbar()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure()
ax=Axes3D(fig)
X=np.arange(-4,4,.3)
Y=np.arange(-4,4,.3)
X, Y =np.meshgrid(X,Y)
R=np.sqrt(x**2 + y**2)
Z=np.sin(R)
ax.plot_surface(X,Y,Z, rstride=1, cstride=1, cmap="jet")

# %% [markdown]
# Matplotlib es una biblioteca de Python especializada en el desarrollo de gráficos bidimensionales incluso 3D

# %%
x=[1,2,3,4]
y=[1,4,9,16]
plt.plot(x,y,'ro')
plt.axis=([0,5,0,20])
plt.title("My First Plot", fontsize=20, fontname="DejaVu Sans")
plt.xlabel('Counting',color="red")
plt.ylabel('Square values',color="blue")
# Out:
# Text(0, 0.5, 'Square values')

# %%
x=[1,2,3,4]
y=[1,4,9,16]
plt.plot(x,y,'ro')
plt.axis=([0,5,0,20])
plt.title("My First Plot", fontsize=20, fontname="DejaVu Sans")
plt.xlabel('Counting',color="red")
plt.ylabel('Square values',color="blue")
plt.text(1,1.5,"First")
plt.text(2,4.5,"Second")
plt.text(3,16.5,"Third")
plt.text(1.1,12,r'$y=x^2$', fontsize=20, bbox= {'facecolor':'yellow','alpha':0.2})  
plt.grid(True)
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.plot([1,2,3,4],[0.5,2.5,4,12],'b*')
plt.legend(['First Series','Second series','Third series'],loc=4)

# %%
import datetime
events=[datetime.date(2019,1,23),
       datetime.date(2019,1,28),
       datetime.date(2019,2,3),
       datetime.date(2019,2,21),
       datetime.date(2019,3,15),
       datetime.date(2019,3,24),
       datetime.date(2019,4,8),
       datetime.date(2019,4,24)]
readings=[12,22,25,20,18,15,17,14]
plt.plot(events,readings)

# %%
x=np.arange(-2*np.pi,2*np.pi,0.01)
y=np.sin(3*x)/x
plt.plot(x,y)

# %%
x=np.arange(-2*np.pi,2*np.pi,0.01)
y=np.sin(3*x)/x
y2=np.sin(2*x)/x
y3=np.sin(4*x)/x
plt.plot(x,y,color='b')
plt.plot(x,y2,color='r')
plt.plot(x,y3,color='g')
plt.xticks([-2*np.pi,-np.pi,0,np.pi,2*np.pi],[r'$-2\pi$',r'$-pi$',r'$0$',r'$+\pi$',r'$+2\pi$' ])
plt.yticks([-1,0,+1,+2,+3],[ r'$-1$',r'$0$',r'$+1$',r'$+2$',r'$+3$'])

ax=plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

# %%
import pandas as pd
data={'series1':[1,3,4,3,5],
    'series2':[2,4,5,2,4],
    'series3':[3,2,3,1,3]}
df=pd.DataFrame(data)
x=np.arange(5) 
plt.plot(x,df)
#plt.axis([0,5,0,7])
plt.legend(data,loc=2)

# %%
df=pd.DataFrame(np.random.rand(6,4), index=['one','two','three','four','five','six'],
               columns=pd.Index(['A','B','C','D'],name="Genus"))
df
df.plot.bar()

# %%
pop=np.random.randint(0,100,100)
plt.hist(pop,bins=10)
# Out:
# (array([ 9., 14.,  5., 10.,  6.,  4.,  7.,  5.,  9.,  3.,  6.,  9.,  5.,
#          3.,  5.]),
#  array([ 1.        ,  7.53333333, 14.06666667, 20.6       , 27.13333333,
#         33.66666667, 40.2       , 46.73333333, 53.26666667, 59.8       ,
#         66.33333333, 72.86666667, 79.4       , 85.93333333, 92.46666667,
#         99.        ]),
#  <a list of 15 Patch objects>)

# %%
sorted_ratings=np.random.random(10) 
Years=np.arange(1921,1940)  
x_pos=np.arange(len(sorted_ratings))
plt.bar(x_pos,sorted_ratings)
plt.suptitle('Ratings based on years',fontsize=14)
plt.xticks(x_pos,Years)
plt.ylabel('Rating',fontsize=12)
plt.xlabel('Year',fontsize=12)
# Out:
# Text(0.5, 0, 'Year')

# %%
index=np.arange(5)
values1=[5,7,3,4,6]
std1=[0.8,1,0.4,0.9,3]
plt.title('A Horizontal Bar Char')
plt.barh(index,values1,xerr=std1,error_kw={'ecolor':'0.1','capsize':6}, alpha=0.7,
        label='First')
plt.yticks(index+0.4,['A','B','C','D','E'])
plt.legend(loc=5)

# %%
labels=['Nokia','Samsung','Apple','Lumia']
values=[10,30,45,15]
colors=['yellow','green','red','blue']
explode=[0.3,0,0,0]
plt.title('A Pie Chart')
plt.pie(values,labels=labels,colors=colors,explode=explode,shadow=True,autopct='%1.1f%%',startangle=180)
#plt.axis('equal')
# Out:
# ([<matplotlib.patches.Wedge at 0x233f3dc22b0>,
# ...
#  [Text(-1.3314791207879568, -0.43262379835803, 'Nokia'),
#   Text(5.149471664411206e-08, -1.0999999999999988, 'Samsung'),
#   Text(0.7778174228929382, 0.7778174957174647, 'Apple'),
#   Text(-0.9801071906340714, 0.4993895221842248, 'Lumia')],
#  [Text(-0.8559508633636865, -0.27811529894444786, '10.0%'),
#   Text(2.8088027260424755e-08, -0.5999999999999993, '30.0%'),
#   Text(0.4242640488506935, 0.4242640885731625, '45.0%'),
#   Text(-0.5346039221640388, 0.27239428482775896, '15.0%')])

# %%
import matplotlib.pyplot as plt
import numpy as np
labels=['Lenguaje Extranjera','Ciencias Computacionales','Ingeniería','Matemáticas','Biologia','Física','Humanidades','Educación','Quimica Analítica']
values=[4,21,19,15,10,9,8,7,7] 
colors=['yellow','green','red','blue']
explode=[0,0,0.2,0,0,0,0,0,0] 
plt.title('Carreras')
plt.pie(values,labels=labels,explode=explode,shadow=True,autopct='%1.1f%%',startangle=180)
#plt.axis('equal')
# Out:
# ([<matplotlib.patches.Wedge at 0x233f3e90c50>,
# ...
#  [Text(-1.0913261718331657, -0.13786655385541455, 'Lenguaje Extranjera'),
#   Text(-0.6741977818040066, -0.8691704959388332, 'Ciencias Computacionales'),
#   Text(0.7307083328203673, -1.0752047862369658, 'Ingeniería'),
#   Text(1.0951181655217817, 0.10351909748547851, 'Matemáticas'),
#   Text(0.7011664053880502, 0.8475645532673017, 'Biologia'),
#   Text(0.10351914875166068, 1.0951181606757014, 'Física'),
#   Text(-0.4683572225853322, 0.9953097568356064, 'Humanidades'),
#   Text(-0.8691705117195713, 0.6741977614596023, 'Educación'),
#   Text(-1.0735084379079578, 0.23995756654128741, 'Quimica Analítica')],
#  [Text(-0.5952688209999085, -0.07519993846658975, '4.0%'),
#   Text(-0.3677442446203672, -0.47409299778481806, '21.0%'),
#   Text(0.44966666635099517, -0.6616644838381328, '19.0%'),
#   Text(0.5973371811936989, 0.056464962264806455, '15.0%'),
#   Text(0.3824544029389364, 0.4623079381458009, '10.0%'),
# ...

# %%
data={'series1':[1,3,4,3,5],'series2':[2,4,5,2,4],'series3':[3,2,3,1,3]}
df=pd.DataFrame(data)
df['series1'].plot(kind='pie',figsize=(6,6))

# %%
xs=np.random.randint(30,40,100)
ys=np.random.randint(20,30,100)
zs=np.random.randint(10,20,100)

xs2=np.random.randint(50,60,100)
ys2=np.random.randint(30,40,100)
zs2=np.random.randint(50,70,100)

xs3=np.random.randint(10,30,100)
ys3=np.random.randint(40,50,100)
zs3=np.random.randint(40,50,100)

fig=plt.figure()
ax=Axes3D(fig)
ax.scatter(xs,ys,zs)
ax.scatter(xs2,ys2,zs2,c='r',marker='^')
ax.scatter(xs3,ys3,zs3,c='g',marker='*')
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
# Out:
# Text(0.5, 0, 'Z Label')

# %%
#Multipaneles
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])
inner_ax=fig.add_axes([0.6,0.6,0.25,0.25])
x1=np.arange(10)
y1=np.array([1,2,7,1,5,2,4,2,3,1])
x2=np.arange(10)
y2=np.array([1,3,4,5,4,5,2,6,4,3])
ax.plot(x1,y1)
inner_ax.plot(x2,y2)

# %%
fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)

# %%
#Generar con numpy un fichero .csv con esos datos
